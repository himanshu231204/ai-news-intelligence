# %% [markdown]
# # Notebook for twitterLinked module: .\app\collectors\twitter.py

# %%
# Quick import smoke testimport importlibmodule_path = 'app.collectors.twitter'importlib.import_module(module_path)print(f'Imported {module_path}')
