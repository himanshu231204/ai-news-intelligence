# %% [markdown]
# # Notebook for collect_newsLinked module: .\app\graph\nodes\collect_news.py

# %%
# Quick import smoke testimport importlibmodule_path = 'app.graph.nodes.collect_news'importlib.import_module(module_path)print(f'Imported {module_path}')
