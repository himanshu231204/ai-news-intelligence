# %% [markdown]
# # Notebook for test_smokeLinked module: .\tests\test_smoke.py

# %%
# Quick import smoke testimport importlibmodule_path = 'tests.test_smoke'importlib.import_module(module_path)print(f'Imported {module_path}')
